# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import filter_data 
import imp
# from pandasql import sqldf

imp.reload(filter_data)
pd.options.display.max_rows = 26
pd.options.display.max_columns = 99
import consts
imp.reload(consts)
# Out:
# C:\Users\Bengo\AppData\Local\Temp\ipykernel_21144\3715591918.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'consts' from 'd:\\Ben\\FinalDSProj\\consts.py'>

# %%
from pandasql import sqldf

# %%
df_inputs = pd.read_csv("filtered\\input_events_filtered_by_subject_id_and_medicine.csv")

# %%
output = sqldf("select * from df_inputs")

# %%
output
# Out:
#         Unnamed: 0  subject_id   hadm_id   stay_id            starttime  \
# 0                0    13441205  22367569  31851222  2171-02-24 14:15:00
# 1                1    13441205  22367569  31851222  2171-02-24 16:49:00
# 2                2    13441205  22367569  31851222  2171-02-24 16:00:00
# 3                3    13441205  22367569  31851222  2171-02-24 14:30:00
# 4                4    13441205  22367569  31851222  2171-02-24 13:18:00
# ...            ...         ...       ...       ...                  ...
# 348672      348672    19990427  29695607  34058245  2182-01-14 10:40:00
# 348673      348673    19990427  29695607  34058245  2182-01-15 02:12:00
# 348674      348674    19990427  29695607  34058245  2182-01-14 10:45:00
# 348675      348675    19990427  29695607  34058245  2182-01-15 01:29:00
# 348676      348676    19990427  29695607  34058245  2182-01-15 02:55:00
#
#                     endtime            storetime  itemid    amount amountuom  \
# ...

# %%
df_inputs[df_inputs["subject_id"] == 19004463][df_inputs["itemid_label"] == "Norepinephrine"].sort_values(by=["starttime"])
# Out:
# C:\Users\Bengo\AppData\Local\Temp\ipykernel_7868\1923336736.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_inputs[df_inputs["subject_id"] == 19004463][df_inputs["itemid_label"] == "Norepinephrine"].sort_values(by=["starttime"])
#     Unnamed: 0  subject_id   hadm_id   stay_id            starttime  \
# 14          14    19004463  24357541  39101627  2177-01-30 09:23:00
# 12          12    19004463  24357541  39101627  2177-01-30 09:45:00
# 13          13    19004463  24357541  39101627  2177-01-30 11:03:00
#
#                 endtime            storetime  itemid    amount amountuom  \
# 14  2177-01-30 09:45:00  2177-01-30 09:23:00  221906  0.335238        mg
# 12  2177-01-30 11:03:00  2177-01-30 10:00:00  221906  1.069502        mg
# 13  2177-01-30 11:31:00  2177-01-30 10:51:00  221906  0.213242        mg
#
#         rate     rateuom  orderid  linkorderid ordercategoryname  \
# 14  0.200238  mcg/kg/min  9491717      9491717          01-Drips
# ...
